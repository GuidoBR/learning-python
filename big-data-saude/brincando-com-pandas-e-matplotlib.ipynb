# %%
data_file = "obitos-infantis-2010-2013-brasil.csv"

# %%
import pandas

# %%
dados = pandas.read_csv(data_file, sep=";")
dados.head(10)
# Out:
#                   Região    RO    AC    AM   RR    PA    AP    TO    MA    PI  \
# 0         1 Região Norte  1588  1097  5017  636  9648  1208  1464     -     -
# 1      2 Região Nordeste     -     -     -    -     -     -     -  7398  3238
# 2       3 Região Sudeste     -     -     -    -     -     -     -     -     -
# 3           4 Região Sul     -     -     -    -     -     -     -     -     -
# 4  5 Região Centro-Oeste     -     -     -    -     -     -     -     -     -
# 5                  Total  1588  1097  5017  636  9648  1208  1464  7398  3238
# 6                      &   NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#
#     ...       RJ     SP    PR    SC    RS    MS    MT    GO    DF   Total
# 0   ...        -      -     -     -     -     -     -     -     -   20658
# 1   ...        -      -     -     -     -     -     -     -     -   51447
# 2   ...    12083  28439     -     -     -     -     -     -     -   56154
# ...

# %%
dados.describe()
# Out:
#                Total
# count       6.000000
# mean    52558.333333
# std     54693.794561
# min     12422.000000
# 25%     17910.000000
# 50%     36052.500000
# 75%     54977.250000
# max    157675.000000

# %%
import matplotlib.pyplot as pyplot
import matplotlib

# %%
matplotlib.style.use('ggplot')
dados.plot(kind="hist")
pyplot.show()
